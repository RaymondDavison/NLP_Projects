# %% [markdown]
# # Using Stopwords from four Major Python Libraries
#
# A. Raymond Anumaneh,  email: aakomonehraymond@yahoo.com  [GitHub](https://github.com/RaymondDavison),  [LinkedIn](https://www.linkedin.com/in/akomoneh-raymond-anumaneh-72955673/)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-Stopwords-from-four-Major-Python-Libraries" data-toc-modified-id="Using-Stopwords-from-four-Major-Python-Libraries-1">Using Stopwords from four Major Python Libraries</a></span></li><li><span><a href="#1.-The-StopWords-package" data-toc-modified-id="1.-The-StopWords-package-2">1. The StopWords package</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.1--Installation" data-toc-modified-id="1.1--Installation-2.0.1">1.1  Installation</a></span></li><li><span><a href="#1.2-Basic-usage" data-toc-modified-id="1.2-Basic-usage-2.0.2">1.2 Basic usage</a></span></li><li><span><a href="#1.3-Python-compatibility" data-toc-modified-id="1.3-Python-compatibility-2.0.3">1.3 Python compatibility</a></span></li></ul></li></ul></li><li><span><a href="#2.-Using-Python's-NLTK-Library" data-toc-modified-id="2.-Using-Python's-NLTK-Library-3">2. Using Python's <a href="https://www.nltk.org/" target="_blank">NLTK Library</a></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.1-Adding-Stop-Words-to-Default-NLTK-Stop-Word-List" data-toc-modified-id="2.1-Adding-Stop-Words-to-Default-NLTK-Stop-Word-List-3.0.1">2.1 Adding Stop Words to Default NLTK Stop Word List</a></span></li><li><span><a href="#2.2-Removing-Stop-Words-from-Default-NLTK-Stop-Word-List" data-toc-modified-id="2.2-Removing-Stop-Words-from-Default-NLTK-Stop-Word-List-3.0.2">2.2 Removing Stop Words from Default NLTK Stop Word List</a></span></li></ul></li></ul></li><li><span><a href="#3.-Using-Python's-Gensim-Library" data-toc-modified-id="3.-Using-Python's-Gensim-Library-4">3. Using Python's <a href="https://pypi.org/project/gensim/" target="_blank">Gensim Library</a></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#3.1-install-gensim-with-conda-run" data-toc-modified-id="3.1-install-gensim-with-conda-run-4.0.1">3.1 install gensim with conda run</a></span></li><li><span><a href="#3.2-Description" data-toc-modified-id="3.2-Description-4.0.2">3.2 Description</a></span></li><li><span><a href="#3.3-Adding-and-Removing-Stop-Words-in-Default-Gensim-Stop-Words-List" data-toc-modified-id="3.3-Adding-and-Removing-Stop-Words-in-Default-Gensim-Stop-Words-List-4.0.3">3.3 Adding and Removing Stop Words in Default Gensim Stop Words List</a></span></li><li><span><a href="#3.4-Removing-Stop-Words-from-Default-Gensim-Stopword-List" data-toc-modified-id="3.4-Removing-Stop-Words-from-Default-Gensim-Stopword-List-4.0.4">3.4 Removing Stop Words from Default Gensim Stopword List</a></span></li></ul></li></ul></li><li><span><a href="#4.-Using-the-SpaCy-Library" data-toc-modified-id="4.-Using-the-SpaCy-Library-5">4. Using the SpaCy Library</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#4.1-Installation" data-toc-modified-id="4.1-Installation-5.0.1">4.1 Installation</a></span></li><li><span><a href="#4.2-Adding-Stop-Words-to-Default-SpaCy-Stop-Words-List" data-toc-modified-id="4.2-Adding-Stop-Words-to-Default-SpaCy-Stop-Words-List-5.0.2">4.2 Adding Stop Words to Default SpaCy Stop Words List</a></span></li><li><span><a href="#4.3-Using-Custom-Script-to-Remove-Stop-Words" data-toc-modified-id="4.3-Using-Custom-Script-to-Remove-Stop-Words-5.0.3">4.3 Using Custom Script to Remove Stop Words</a></span></li></ul></li></ul></li><li><span><a href="#5.-Remove-stopwords-from-a-wikipedia-article" data-toc-modified-id="5.-Remove-stopwords-from-a-wikipedia-article-6">5. Remove stopwords from a wikipedia article</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#5.1-Function-to-plot-Word-Clord" data-toc-modified-id="5.1-Function-to-plot-Word-Clord-6.0.1">5.1 Function to plot Word Clord</a></span></li><li><span><a href="#5.2-Remove-Stopwords-from-a-wikipedia-article" data-toc-modified-id="5.2-Remove-Stopwords-from-a-wikipedia-article-6.0.2">5.2 Remove Stopwords from a wikipedia article</a></span></li><li><span><a href="#5.3-Plotting-a-wordcloud-for-a-wikipedia-article" data-toc-modified-id="5.3-Plotting-a-wordcloud-for-a-wikipedia-article-6.0.3">5.3 Plotting a wordcloud for a wikipedia article</a></span></li><li><span><a href="#5.4-Plotting-a-wordcloud-for-Ghanaian-wikipedia--page" data-toc-modified-id="5.4-Plotting-a-wordcloud-for-Ghanaian-wikipedia--page-6.0.4">5.4 Plotting a wordcloud for <em>Ghanaian</em> wikipedia  page</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 1. The StopWords package
#
# Python-stop-words has been originally developed for Python 2, but has been ported and tested for Python 3.
#
# Available Languages are as follows:
#
# - Available languages
# - Arabic
# - Bulgarian
# - Catalan
# - Czech
# - Danish
# - Dutch
# - English
# - Finnish
# - French
# - German
# - Hungarian
# - Indonesian
# - Italian
# - Norwegian
# - Polish
# - Portuguese
# - Romanian
# - Russian
# - Spanish
# - Swedish
# - Turkish
# - Ukrainian
# ### 1.1  Installation
# stop-words is available on PyPI
#
# http://pypi.python.org/pypi/stop-words
#
# So easily install it by pip
#
# `$ pip install stop-words`
# Or by `easy_install`
#
# `$ easy_install stop-words`
# Another way is by cloning stop-words’s git repo
#
# `$ git clone --recursive git://github.com/Alir3z4/python-stop-words.git`
# Then install it by running:
#
# `$ python setup.py install`
# ### 1.2 Basic usage
# `from stop_words import get_stop_words`
#
# `stop_words = get_stop_words('en')`
#
# `stop_words = get_stop_words('english')`
#
# `from stop_words import safe_get_stop_words`
#
# `stop_words = safe_get_stop_words('unsupported language')`
#
# ### 1.3 Python compatibility
# Python-stop-words has been originally developed for Python 2, but has been ported and tested for Python 3.

# %%
pip install stop-words
# Out:
# ...
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32916 sha256=529b3903238faf7e8459ae7eb4710be42d3de3d35603c0100ca6879880d6df08
#   Stored in directory: c:\users\aakom\appdata\local\pip\cache\wheels\eb\03\0d\3bd31c983789aeb0b4d5e2ca48590288d9db1586cf5f225062
# Successfully built stop-words
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stop_words import get_stop_words

# %%
pypl_stop_words = get_stop_words('en')

# %%
len(pypl_stop_words)
# Out:
# 174

# %% [markdown]
# # 2. Using Python's [NLTK Library](https://www.nltk.org/)
#
# The NLTK library is one of the oldest and most commonly used Python libraries for Natural Language Processing. NLTK supports stop word removal, and you can find the list of stop words in the corpus module. To remove stop words from a sentence, you can divide your text into words and then remove the word if it exits in the list of stop words provided by NLTK.
#
# Let's see a simple example:

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize

#text = "Nick likes to play football, however he is not too fond of tennis."
#text_tokens = word_tokenize(text)

#tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

#print(tokens_without_sw)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aakom\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aakom\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
nltk_stopwords = stopwords.words()
len(nltk_stopwords)
# Out:
# 6800

# %% [markdown]
# Probably this is the list of **all the stop words in nltk**.
#
# Lets check the list of english stopwords in nltk

# %%
en_nltk_stopwords = stopwords.words('english')
print(len(en_nltk_stopwords), en_nltk_stopwords)
# Out:
# 179 ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'th
# ...

# %% [markdown]
# ### 2.1 Adding Stop Words to Default NLTK Stop Word List
# To add a word to NLTK stop words collection, first create an object from the `stopwords.words('english')` list. Next, use the `append()` method on the list to add any word to the list.
#
# The following script adds the word play to the NLTK stop word collection. Again, we remove all the words from our text variable to see if the word play is removed or not.

# %%
en_nltk_stopwords.append('play')

'play' in en_nltk_stopwords
# Out:
# True

# %% [markdown]
# ### 2.2 Removing Stop Words from Default NLTK Stop Word List
#
# `en_nltk_stopwords.remove('word') method`.

# %%
en_nltk_stopwords.remove('play')

'play' in en_nltk_stopwords
# Out:
# False

# %% [markdown]
# # 3. Using Python's [Gensim Library](https://pypi.org/project/gensim/)
#
# The [Gensim](https://stackabuse.com/python-for-nlp-working-with-the-gensim-library-part-1/) library is another extremely useful library for removing stop words from a string in Python. All you have to do is to import the ``remove_stopwords()`` method from the `gensim.parsing.preprocessing` module. Next, you need to pass your sentence from which you want to remove stop words, to the `remove_stopwords()` method which returns text string without the stop words.
#
# Let's take a look at a simple example of how to remove stop words via the Gensim library.

# %% [markdown]
# ### 3.1 install gensim with conda run
#
# `conda install -c anaconda gensim`

# %% [markdown]
# ### 3.2 Description
# **Gensim** is a Python library for **topic modelling**, **document indexing** and **similarity retrieval** with large corpora. Target audience is the **natural language processing (NLP)** and **information retrieval (IR)** community.

# %%
# conda install -c anaconda gensim

# or

# pip install --upgrade gensim
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.parsing.preprocessing import remove_stopwords

text = "Nick likes to play football, however he is not too fond of tennis."
filtered_sentence = remove_stopwords(text)

print(filtered_sentence)
# Out:
# Nick likes play football, fond tennis.

# %% [markdown]
# ### 3.3 Adding and Removing Stop Words in Default Gensim Stop Words List

# %%
import gensim
gensim_stopwords = gensim.parsing.preprocessing.STOPWORDS
print(gensim_stopwords)
# Out:
# frozenset({'did', 'nobody', 'they', 'have', 'your', 'why', 'only', 'fifteen', 'the', 'becoming', 'with', 'thereafter', 'various', 'more', 'thereby', 'anyhow', 'yet', 'hers', 'can', 'always', 'nine', 'next', 'others', 'yourself', 'cry', 'a', 'though', 'several', 'of', 'call', 'both', 'hereafter', 'are', 'him', 'using', 'km', 'then', 'afterwards', 'seeming', 'now', 'any', 'she', 'somewhere', 'unless', 'as', 'still', 'am', 'another', 'had', 'system', 'between', 'least', 'inc', 'enough', 'doesn', 'move', 'us', 'five', 'part', 'together', 'whatever', 'used', 'at', 'became', 'that', 'mostly', 'although', 'give', 'eight', 'during', 'than', 'six', 'serious', 'thru', 'onto', 'please', 'were', 'or', 'while', 'last', 'before', 'but', 'myself', 'sincere', 'where', 'out', 'do', 'due', 'too', 'among', 'indeed', 'whose', 'by', 'was', 'less', 'such', 'again', 'how', 'an', 'describe', 'two', 'via', 'from', 'after', 'no', 'regarding', 'detail', 'something', 'above', 'further', 'anything', 'seems', 've
# ...

# %%
len(gensim_stopwords)
# Out:
# 337

# %%
from gensim.parsing.preprocessing import STOPWORDS

all_stopwords_gensim = STOPWORDS.union(set(['likes', 'play']))

text = "Nick likes to play football, however he is not too fond of tennis."
text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in all_stopwords_gensim]

print(tokens_without_sw)
# Out:
# ['Nick', 'football', ',', 'fond', 'tennis', '.']

# %% [markdown]
# ### 3.4 Removing Stop Words from Default Gensim Stopword List
#
# To remove stop words from Gensim's list of stop words, you have to call the difference() method on the frozen set object, which contains the list of stop words. You need to pass a set of stop words that you want to remove from the frozen set to the difference() method. The difference() method returns a set which contains all the stop words except those passed to the difference() method.
#
# The following script removes the word not from the set of stop words in Gensim:

# %%
from gensim.parsing.preprocessing import STOPWORDS

all_stopwords_gensim = STOPWORDS
sw_list = {"not"}
all_stopwords_gensim = STOPWORDS.difference(sw_list)

text = "Nick likes to play football, however he is not too fond of tennis."
text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in all_stopwords_gensim]

print(tokens_without_sw)
# Out:
# ['Nick', 'likes', 'play', 'football', ',', 'not', 'fond', 'tennis', '.']

# %% [markdown]
# # 4. Using the SpaCy Library
#
# The SpaCy library in Python is yet another extremely useful language for natural language processing in Python.
#
# To install SpaCy, you have to execute the following script on your command terminal:
#
#
# ### 4.1 Installation
#
# `$ pip install -U spacy`

# %% [markdown]
# Once the library is downloaded, you also need to download the language model. Several models exist in SpaCy for different languages. We will be installing the English language model. Execute the following command in your terminal:
#
# `$ python -m spacy download en`
#
# Once the language model is downloaded, you can remove stop words from text using SpaCy. Look at the following script:

# %%
import spacy
sp = spacy.load('en_core_web_sm')

spacy_stopwords = sp.Defaults.stop_words

#text = "Nick likes to play football, however he is not too fond of tennis."
#text_tokens = word_tokenize(text)
#tokens_without_sw= [word for word in text_tokens if not word in all_stopwords]

len(spacy_stopwords)
# Out:
# 326

# %%
print(spacy_stopwords)
# Out:
# {'did', 'nobody', '’ll', '‘d', 'they', "'m", 'have', 'why', 'your', 'only', 'fifteen', 'the', 'becoming', 'with', 'thereafter', 'more', 'thereby', 'various', 'anyhow', 'can', 'hers', 'yet', 'always', 'nine', 'next', 'others', 'yourself', 'a', 'though', 'several', 'of', 'call', 'both', 'are', 'hereafter', 'him', 'then', 'using', 'afterwards', 'seeming', '’m', 'now', 'any', 'she', 'n’t', 'somewhere', 'unless', 'as', 'still', 'am', 'another', 'had', 'between', 'least', 'enough', 'move', 'us', 'five', 'part', '‘m', 'together', 'whatever', 'used', 'at', 'became', 'that', 'mostly', 'although', 'give', 'eight', 'during', 'than', 'six', 'serious', 'thru', 'onto', 'please', 'were', 'or', 'while', 'last', 'before', 'but', 'myself', 'where', 'out', 'do', 'due', 'too', 'among', 'indeed', 'whose', 'by', 'was', 'less', 'such', 'again', 'how', 'an', 'two', "'ll", 'via', 'from', 'after', 'no', 'regarding', 'something', 'above', 'further', '’d', 'anything', 'seems', 'very', 'back', 'full', 'keep', 'n
# ...

# %% [markdown]
# ### 4.2 Adding Stop Words to Default SpaCy Stop Words List
#
# The SpaCy stop word list is basically a set of strings. You can add a new word to the set like you would add any new item to a set.
#
# Look at the following script in which we add the word tennis to existing list of stop words in Spacy:

# %%
spacy_stopwords.add("tennis")
"tennis" in spacy_stopwords
# Out:
# True

# %%
spacy_stopwords.remove('not')
"tennis" in spacy_stopwords
# Out:
# True

# %% [markdown]
# ### 4.3 Using Custom Script to Remove Stop Words
#
# In the previous section, you saw different how we can use various libraries to remove stop words from a string in Python. If you want full control over stop word removal, you can write your own script to remove stop words from your string.
#
# The first step in this regard is to define a list of words that you want treated as stop words. Let's create a list of some of the most commonly used stop words:

# %%
my_stopwords = spacy_stopwords

def remove_mystopwords(sentence):
    tokens = sentence.split(" ")
    tokens_filtered= [word for word in tokens if not word in my_stopwords]
    return (" ").join(tokens_filtered)

# %% [markdown]
# Let's now try to remove stop words from a sample sentence:

# %%
text = "Nick likes to play football, however he is not too fond of tennis."
filtered_text = remove_mystopwords(text)
print(filtered_text)
# Out:
# Nick likes play football, not fond tennis.

# %%
'not' in my_stopwords
# Out:
# False

# %%
len(text)
# Out:
# 66

# %%
text_tokens1 = word_tokenize(text)
len(text_tokens1)
# Out:
# 15

# %%
filtered_text1 = word_tokenize(filtered_text)
len(filtered_text1)
# Out:
# 9

# %% [markdown]
# # 5. Remove stopwords from a wikipedia article

# %% [markdown]
# ### 5.1 Function to plot Word Clord

# %%
# Function to plot Word Clord

def plot_wordcloud(text, new_stopwords, color):
    # Create stopword list:
    stopwords = set(STOPWORDS)
    stopwords.update(new_stopwords)
    wordcloud = WordCloud(stopwords=stopwords, width = 500, height = 500, 
                          background_color=color, colormap="ocean",  random_state=1123).generate(text)
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud)
    plt.axis("off");

# %% [markdown]
# ### 5.2 Remove Stopwords from a wikipedia article

# %%
import wikipedia

import matplotlib.pyplot as plt
Love_text = wikipedia.page("The Love Song of J. Alfred Prufrock")
Love_text1 = result.content
#print(final_result)
print(len(Love_text1), '\n\n')
print(love_text)

#love_text = wikipedia.summary("The Love Song of J. Alfred Prufrock")

#result= wikipedia.summary("MachineLearning", sentences=5)
# Out:
# 15810
#
#
# "The Love Song of J. Alfred Prufrock", commonly known as "Prufrock", is the first professionally published poem by American-born British poet T. S. Eliot (1888–1965). Eliot began writing "Prufrock" in February 1910, and it was first published in the June 1915 issue of Poetry: A Magazine of Verse at the instigation of Ezra Pound (1885–1972). It was later printed as part of a twelve-poem pamphlet (or chapbook) titled Prufrock and Other Observations in 1917. At the time of its publication, Prufrock was considered outlandish, but is now seen as heralding a paradigmatic cultural shift from late 19th-century Romantic verse and Georgian lyrics to Modernism.
# ...

# %%
# Tokenize this text with word tokenizer from NLTK and count the tokens
love_tokens = word_tokenize(Love_text1)

print(len(love_tokens))
# Out:
# 3169

# %%
print(love_tokens)
# Out:
# ['``', 'The', 'Love', 'Song', 'of', 'J.', 'Alfred', 'Prufrock', "''", ',', 'commonly', 'known', 'as', '``', 'Prufrock', "''", ',', 'is', 'the', 'first', 'professionally', 'published', 'poem', 'by', 'American-born', 'British', 'poet', 'T.', 'S.', 'Eliot', '(', '1888–1965', ')', '.', 'Eliot', 'began', 'writing', '``', 'Prufrock', "''", 'in', 'February', '1910', ',', 'and', 'it', 'was', 'first', 'published', 'in', 'the', 'June', '1915', 'issue', 'of', 'Poetry', ':', 'A', 'Magazine', 'of', 'Verse', 'at', 'the', 'instigation', 'of', 'Ezra', 'Pound', '(', '1885–1972', ')', '.', 'It', 'was', 'later', 'printed', 'as', 'part', 'of', 'a', 'twelve-poem', 'pamphlet', '(', 'or', 'chapbook', ')', 'titled', 'Prufrock', 'and', 'Other', 'Observations', 'in', '1917', '.', 'At', 'the', 'time', 'of', 'its', 'publication', ',', 'Prufrock', 'was', 'considered', 'outlandish', ',', 'but', 'is', 'now', 'seen', 'as', 'heralding', 'a', 'paradigmatic', 'cultural', 'shift', 'from', 'late', '19th-century', 'Roman
# ...

# %%
# Remove stop words
#remove_mystopwords(love_tokens)
love_tokens = [word for word in love_tokens if not word in spacy_stopwords]

print(len(love_tokens))
# Out:
# 2065

# %%
print(spacy_stopwords)
# Out:
# {'did', 'nobody', '’ll', '‘d', 'they', 'tennis', "'m", 'have', 'why', 'your', 'only', 'fifteen', 'the', 'becoming', 'with', 'thereafter', 'more', 'thereby', 'various', 'anyhow', 'can', 'hers', 'yet', 'always', 'nine', 'next', 'others', 'yourself', 'a', 'though', 'several', 'of', 'call', 'both', 'are', 'hereafter', 'him', 'then', 'using', 'afterwards', 'seeming', '’m', 'now', 'any', 'she', 'n’t', 'somewhere', 'unless', 'as', 'still', 'am', 'another', 'had', 'between', 'least', 'enough', 'move', 'us', 'five', 'part', '‘m', 'together', 'whatever', 'used', 'at', 'became', 'that', 'mostly', 'although', 'give', 'eight', 'during', 'than', 'six', 'serious', 'thru', 'onto', 'please', 'were', 'or', 'while', 'last', 'before', 'but', 'myself', 'where', 'out', 'do', 'due', 'too', 'among', 'indeed', 'whose', 'by', 'was', 'less', 'such', 'again', 'how', 'an', 'two', "'ll", 'via', 'from', 'after', 'no', 'regarding', 'something', 'above', 'further', '’d', 'anything', 'seems', 'very', 'back', 'full', 
# ...

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
love_tokens = TreebankWordDetokenizer().detokenize(love_tokens)

# %% [markdown]
# ### 5.3 Plotting a wordcloud for a wikipedia article

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

#plot_wordcloud(love_tokens, spacy_stopwords, 'green')

plt.figure(figsize=(10, 10))
wordcloud = WordCloud(width = 500, height = 500, background_color='green', colormap="ocean",  
                      random_state=1124).generate(love_tokens)
plt.imshow(wordcloud)
plt.axis("off");

# %% [markdown]
# Modify plot_wordcloud to detokenize

# %%
def plot_wordcloud(text, new_stopwords, color):
    # Create stopword list:
    stopwords = set(STOPWORDS)
    stopwords.update(new_stopwords)
    wordcloud = WordCloud(stopwords=stopwords, width = 500, height = 500, 
                          background_color=color, colormap="ocean",  random_state=1123).generate(text)
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud)
    plt.axis("off");

# %% [markdown]
# ### 5.4 Plotting a wordcloud for _Ghanaian_ wikipedia  page

# %%
cameroon = wikipedia.page("Ghanaian")
cameroon_text = cameroon.content
plot_wordcloud(cameroon_text, spacy_stopwords, 'black')
